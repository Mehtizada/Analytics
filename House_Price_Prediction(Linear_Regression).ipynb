# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehtizada/Analytics/blob/main/House_Price_Prediction(Linear_Regression).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# HOUSE PRICE PREDICTION (Linear Regression)

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
n = 150

# %%
area = np.random.normal(120, 25, n)            # house area
price = 800 * area + np.random.normal(0, 5000, n)  # price

# %%
df = pd.DataFrame({
    'area': area,
    'price': price
})

# %%
X = df[['area']]
y = df['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
score = model.score(X_test, y_test)
print("Model R^2:", score)
# Out:
# Model R^2: 0.9189764582460804

# %%
plt.scatter(X_test, y_test, label="Real")
plt.scatter(X_test, model.predict(X_test), label="Predicted")
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("House Price Prediction")
plt.legend()
plt.show()
